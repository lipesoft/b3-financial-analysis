# %%
from scr.coleta_dados import corregar_dados
from src.indicadores import margem_liquida, crescimento_receita
from src.visualizacao import grafico_receita

df = carregar_dados()

df = margem_liquida(df)
df = crescimento_receita(df)

df

# %%
grafico_receita(df, "Petrobras")
